# %% [markdown]
# <a href="https://colab.research.google.com/github/Shazebgk/IITBCourseGithub/blob/master/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('/loan.csv')


# Display the first few rows of the dataframe
print(df.head())

# General information about the dataset
print(df.info())

# Check for missing values
print(df.isnull().sum())

# Check for duplicates
print(df.duplicated().sum())

# Summary statistics
print(df.describe())
# Out:
# <ipython-input-3-2e5fed09be1b>:6: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/loan.csv')
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# ...
